# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Preparation

# %%
df = pd.read_csv('full_db_conversations.csv', names=['conversation_id', 'raw_tweets_info'])
df.head()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-21-bda5ff02aa51> in <module>()
# ----> 1 df = pd.read_csv('full_db_conversations.csv', names=['conversation_id', 'raw_tweets_info'], engine='python')
#       2 df.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     760             self.options['has_index_names'] = kwds['has_index_names']
#     761
# --> 762         self._make_engine(self.engine)
#     763
#     764     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#     970             elif engine == 'python-fwf':
#     971                 klass = FixedWidthFieldParser
# --> 972             self._engine = klass(self.f, **self.options)
#     973
#     974     def _failover_to_python(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, **kwds)
#    1965         # infer column indices from self.usecols if is is specified.
#    1966         self._col_indices = None
# -> 1967         self.columns, self.num_original_columns = self._infer_columns()
#    1968
#    1969         # Now self.columns has the set of columns that we will process.
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _infer_columns(self)
#    2340         else:
#    2341             try:
# -> 2342                 line = self._buffered_line()
#    2343
#    2344             except StopIteration:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _buffered_line(self)
#    2411             return self.buf[0]
#    2412         else:
# -> 2413             return self._next_line()
#    2414
#    2415     def _check_for_bom(self, first_row):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _next_line(self)
#    2516
#    2517             while True:
# -> 2518                 orig_line = self._next_iter_line(row_num=self.pos + 1)
#    2519                 self.pos += 1
#    2520
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _next_iter_line(self, row_num)
#    2576
#    2577         try:
# -> 2578             return next(self.data)
#    2579         except csv.Error as e:
#    2580             if self.warn_bad_lines or self.error_bad_lines:
#
# PermissionError: [Errno 13] Permission denied

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121420 entries, 0 to 121419
# Data columns (total 2 columns):
# conversation_id    121420 non-null int64
# raw_tweets_info    121420 non-null object
# dtypes: int64(1), object(1)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Data Wrangling

# %%
tweet_ids = []
for conv in list(df['raw_tweets_info']):
    ids = []
    for tweet in eval(conv):
        ids.append(tweet[0])
    tweet_ids.append(ids)
print('Sample Tweet ids of conversations')
print(f'{tweet_ids[:5]}\n')

user_ids = []
for conv in list(df['raw_tweets_info']):
    ids = []
    for tweet in eval(conv):
        ids.append(tweet[1]) 
    user_ids.append(ids)

print('Sample user ids in conversation:')
tweet_ids[:5]
# Out:
# Sample Tweet ids of conversations
# [[737293041258647552], [737293037412438016], [737293021918728193], [737293009969131521], [737292996874362880]]
#
# Sample user ids in conversation:
# [[737293041258647552],
#  [737293037412438016],
#  [737293021918728193],
#  [737293009969131521],
#  [737292996874362880]]

# %%
df['tweet_ids'] = tweet_ids
df['user_ids'] = user_ids

# %%
df['conversation_length'] = [len(eval(tweet)) for tweet in list(df['raw_tweets_info'])]

# %%
df.head()
# Out:
#    conversation_id                     raw_tweets_info             tweet_ids  \
# 0                0  [(737293041258647552, 2190151123)]  [737293041258647552]
# 1                1  [(737293037412438016, 3233760050)]  [737293037412438016]
# 2                2  [(737293021918728193, 4149424394)]  [737293021918728193]
# 3                3  [(737293009969131521, 1158379292)]  [737293009969131521]
# 4                4  [(737292996874362880, 3935674999)]  [737292996874362880]
#
#        user_ids  conversation_length
# 0  [2190151123]                    1
# 1  [3233760050]                    1
# 2  [4149424394]                    1
# 3  [1158379292]                    1
# 4  [3935674999]                    1

# %%
df['conversation_length'].value_counts()
# Out:
# 1    118186
# 2      2683
# 3       406
# 4       100
# 5        26
# 6        14
# 8         3
# 7         2
# Name: conversation_length, dtype: int64

# %%
# Get only rows where there actually is a conversation
df = df[df['conversation_length'] > 1]

# %%
# Black magic
keys = ["KLM", "AirFrance", "British_Airways", "AmericanAir", "Lufthansa", "AirBerlin", "AirBerlin assist", "easyJet", "RyanAir", "SingaporeAir", "Qantas", "EtihadAirways", "VirginAtlantic"]
values = ["56377143", "106062176", "18332190", "22536055", "124476322", "26223583", "2182373406", "38676903", "1542862735", "253340062", "218730857", "45621423", "20626359"]
values = [int(value) for value in values]
airline_dict = dict(zip(keys, [int(value) for value in values]))

airlines = []
for row in list(df['user_ids']):
    if bool(set(list(row)).intersection(values)):
        airline_ids = set((list(row))).intersection(values)
        extracted_airlines = [keys for keys,values in airline_dict.items() if values == list(airline_ids)[0]]
        airlines.append(extracted_airlines[0])
    else:
        airlines.append('No airlines involved')

# %%
airlines[:5]
# Out:
# ['easyJet',
#  'No airlines involved',
#  'No airlines involved',
#  'No airlines involved',
#  'No airlines involved']

# %%
df['airlines_involved'] = airlines

# %% [markdown]
# ## Exploration of new dataframe

# %%
df.head()
# Out:
#      conversation_id                                    raw_tweets_info  \
# 160              160  [(737291700041830401, 559531874), (73729097178...
# 323              323  [(738670024022499328, 708474694404608001), (73...
# 326              326  [(738669982469492736, 244617028), (73866955216...
# 410              410  [(738669309191409664, 18137607), (738663994077...
# 426              426  [(738668975538774016, 12274222), (738668761335...
#
#                                              tweet_ids  \
# 160           [737291700041830401, 737290971784859648]
# 323           [738670024022499328, 738664462329221120]
# 326  [738669982469492736, 738669552167444480, 73866...
# 410  [738669309191409664, 738663994077138944, 73866...
# 426           [738668975538774016, 738668761335627776]
#
#                              user_ids  conversation_length  \
# 160             [559531874, 38676903]                    2
# 323  [708474694404608001, 1384797350]                    2
# 326  [244617028, 75848890, 244617028]                    3
# 410    [18137607, 18137607, 18137607]                    3
# 426              [12274222, 12274222]                    2
#
#         airlines_involved
# 160               easyJet
# 323  No airlines involved
# 326  No airlines involved
# 410  No airlines involved
# 426  No airlines involved

# %%
df['airlines_involved'].value_counts().plot(kind='barh', figsize=(15,5))
plt.title('Airline conversation involvement distribution', weight='bold', fontsize=20)
plt.xlabel('Frequency', fontsize=16)
plt.ylabel('Airline', fontsize=16, rotation=45);
#plt.savefig('Airline conversation involvement', dpi=300)

# %% [markdown]
# ## Save to csv

# %%
df.to_csv('conversations_10_jsons.csv', index=False)

# %% [markdown]
# ## Final Check

# %%
df = pd.read_csv('conversations_10_jsons.csv')
display(df.info())
display(df.head())
display(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 6 columns):
# conversation_id        457 non-null int64
# raw_tweets_info        457 non-null object
# tweet_ids              457 non-null object
# user_ids               457 non-null object
# conversation_length    457 non-null int64
# airlines_involved      457 non-null object
# dtypes: int64(2), object(4)
# memory usage: 21.5+ KB
# None
#    conversation_id                                    raw_tweets_info  \
# 0                2  [(739565730891464705, 2158887092), (7395609423...
# 1               58  [(739566848157569027, 157574171), (73951945900...
# 2               77  [(739567295429627904, 219995045), (73955845160...
# 3               83  [(739567393849106432, 79447915), (739515629334...
# 4              206  [(739569215598960640, 141980503), (73919975208...
#
#                                   tweet_ids                  user_ids  \
# 0  [739565730891464705, 739560942376259584]  [2158887092, 2183268807]
# 1  [739566848157569027, 739519459006816256]    [157574171, 157574171]
# 2  [739567295429627904, 739558451601248256]    [219995045, 219995045]
# 3  [739567393849106432, 739515629334626304]      [79447915, 19973673]
# 4  [739569215598960640, 739199752085082112]    [141980503, 141980503]
#
#    conversation_length     airlines_involved
# 0                    2  No airlines involved
# 1                    2  No airlines involved
# 2                    2  No airlines involved
# 3                    2  No airlines involved
# 4                    2  No airlines involved
#        conversation_id  conversation_length
# count       457.000000           457.000000
# mean      40393.037199             2.019694
# std       26844.754970             0.139098
# min           2.000000             2.000000
# 25%       12826.000000             2.000000
# 50%       41958.000000             2.000000
# 75%       63804.000000             2.000000
# max      109916.000000             3.000000
