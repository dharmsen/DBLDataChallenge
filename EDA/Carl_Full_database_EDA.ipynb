# %%
# Dependencies
import numpy as np
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

# %%
# How many rows do you want?
n_rows = 10000
# Connect to database
conn = sqlite3.connect('all_features_database.db')
df = pd.read_sql(f'SELECT * FROM tweets LIMIT {n_rows}', conn)
# %time
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 5.96 µs

# %%
df.head()
# Out:
#                        created_at  favorite_count              id_str  \
# 0  Tue Sep 27 08:17:02 +0000 2016               0  780682646854787072
# 1  Tue Sep 27 08:17:02 +0000 2016               0  780682647429414912
# 2  Tue Sep 27 08:17:04 +0000 2016               0  780682655104991232
# 3  Tue Sep 27 08:17:11 +0000 2016               0  780682685761093632
# 4  Tue Sep 27 08:17:21 +0000 2016               0  780682727993507840
#
#   in_reply_to_status_id_str in_reply_to_user_id_str in_reply_to_screen_name  \
# 0        780678380534497281               107695463            johnnymowlem
# 1                      None                    None                    None
# 2        780678391846625280               165883353           gforsterphoto
# 3                      None                    None                    None
# 4                      None                    None                    None
#
#   lang  retweet_count  retweeted  \
# 0   en              0          0
# 1   fr              0          0
# 2   en              0          0
# 3   en              0          0
# 4   fr              0          0
#
#                                                 text          ...           \
# 0  @johnnymowlem @VirginAtlantic @IMSA @BAR1Motor...          ...
# 1  RT @JulieThoin: L'audience reprend. Examen du ...          ...
# 2  Flew into Gatwick last night. 5 hour drive nor...          ...
# 3  👎🏼 what is with Italy...#nopassport control, I...          ...
# 4              Qqun a déjà voyagé avec RyanAir ici ?          ...
#
#   ('user', 'location')     ('user', 'name') ('user', 'notifications')  \
# 0            London UK       Graham Goodwin                      None
# 1                Paris         Marc Gehring                      None
# 2         Co . Durham   Nicola Jayne Little                      None
# 3               London       Brightlights01                      None
# 4        Nancy, France             Eloïse 🔥                      None
#
#    ('user', 'protected') ('user', 'screen_name')  ('user', 'statuses_count')  \
# 0                      0               dsceditor                       18873
# 1                      0             marcgehring                        5887
# 2                      0         NicolaJSparkles                       35910
# 3                      0          brightlights01                         564
# 4                      0               ThaNicki_                         308
#
#   ('user', 'time_zone')                            ('user', 'url')  \
# 0                  None              http://www.dailysportscar.com
# 1                 Paris                                       None
# 2            Casablanca     http://www.sparklecommunications.co.uk
# 3                London  http://www.catsofnorthlondon.blogspot.com
# 4                  None                                       None
#
#   ('user', 'utc_offset')  ('user', 'verified')
# 0                    NaN                     0
# 1                 7200.0                     0
# 2                 3600.0                     0
# 3                 3600.0                     0
# 4                    NaN                     0
#
# [5 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['created_at', 'favorite_count', 'id_str', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'lang',
#        'retweet_count', 'retweeted', 'text', 'timestamp_ms', 'truncated',
#        '('user', 'created_at')', '('user', 'default_profile')',
#        '('user', 'description')', '('user', 'favourites_count')',
#        '('user', 'follow_request_sent')', '('user', 'followers_count')',
#        '('user', 'following')', '('user', 'friends_count')',
#        '('user', 'geo_enabled')', '('user', 'id_str')', '('user', 'lang')',
#        '('user', 'listed_count')', '('user', 'location')', '('user', 'name')',
#        '('user', 'notifications')', '('user', 'protected')',
#        '('user', 'screen_name')', '('user', 'statuses_count')',
#        '('user', 'time_zone')', '('user', 'url')', '('user', 'utc_offset')',
#        '('user', 'verified')'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 34 columns):
# created_at                         10000 non-null object
# favorite_count                     10000 non-null int64
# id_str                             10000 non-null object
# in_reply_to_status_id_str          2358 non-null object
# in_reply_to_user_id_str            2922 non-null object
# in_reply_to_screen_name            2922 non-null object
# lang                               10000 non-null object
# retweet_count                      10000 non-null int64
# retweeted                          10000 non-null int64
# text                               10000 non-null object
# timestamp_ms                       10000 non-null object
# truncated                          10000 non-null int64
# ('user', 'created_at')             10000 non-null object
# ('user', 'default_profile')        10000 non-null int64
# ('user', 'description')            8036 non-null object
# ('user', 'favourites_count')       10000 non-null int64
# ('user', 'follow_request_sent')    0 non-null object
# ('user', 'followers_count')        10000 non-null int64
# ('user', 'following')              0 non-null object
# ('user', 'friends_count')          10000 non-null int64
# ('user', 'geo_enabled')            10000 non-null int64
# ('user', 'id_str')                 10000 non-null object
# ('user', 'lang')                   10000 non-null object
# ('user', 'listed_count')           10000 non-null float64
# ('user', 'location')               6422 non-null object
# ('user', 'name')                   10000 non-null object
# ('user', 'notifications')          0 non-null object
# ('user', 'protected')              10000 non-null int64
# ('user', 'screen_name')            10000 non-null object
# ('user', 'statuses_count')         10000 non-null int64
# ('user', 'time_zone')              6510 non-null object
# ('user', 'url')                    5014 non-null object
# ('user', 'utc_offset')             6510 non-null float64
# ('user', 'verified')               10000 non-null int64
# dtypes: float64(2), int64(12), object(20)
# memory usage: 2.6+ MB

# %%
df.describe()
# Out:
#        favorite_count  retweet_count  retweeted   truncated  \
# count         10000.0        10000.0    10000.0  10000.0000
# mean              0.0            0.0        0.0      0.0184
# std               0.0            0.0        0.0      0.1344
# min               0.0            0.0        0.0      0.0000
# 25%               0.0            0.0        0.0      0.0000
# 50%               0.0            0.0        0.0      0.0000
# 75%               0.0            0.0        0.0      0.0000
# max               0.0            0.0        0.0      1.0000
#
#        ('user', 'default_profile')  ('user', 'favourites_count')  \
# count                 10000.000000                  10000.000000
# mean                      0.405100                   4908.158200
# std                       0.490936                  19192.550747
# min                       0.000000                      0.000000
# 25%                       0.000000                     13.000000
# 50%                       0.000000                    216.000000
# 75%                       1.000000                   2379.000000
# max                       1.000000                 331775.000000
#
#        ('user', 'followers_count')  ('user', 'friends_count')  \
# count                 1.000000e+04               10000.000000
# mean                  1.155402e+05                6407.309600
# std                   3.866950e+05               18920.131395
# min                   0.000000e+00                   0.000000
# 25%                   1.170000e+02                 114.000000
# 50%                   5.820000e+02                 490.000000
# 75%                   2.722000e+03                1448.000000
# max                   2.200884e+06              161044.000000
#
#        ('user', 'geo_enabled')  ('user', 'listed_count')  \
# count             10000.000000              10000.000000
# mean                  0.375600                762.277000
# std                   0.484302               2177.596305
# min                   0.000000                  0.000000
# 25%                   0.000000                  6.000000
# 50%                   0.000000                 43.000000
# 75%                   1.000000                212.000000
# max                   1.000000              13161.000000
#
#        ('user', 'protected')  ('user', 'statuses_count')  \
# count                10000.0                1.000000e+04
# mean                     0.0                1.318585e+05
# std                      0.0                2.921180e+05
# min                      0.0                1.000000e+00
# 25%                      0.0                1.661000e+03
# 50%                      0.0                1.118450e+04
# 75%                      0.0                8.171200e+04
# max                      0.0                1.718749e+06
#
#        ('user', 'utc_offset')  ('user', 'verified')
# count             6510.000000          10000.000000
# mean               875.806452              0.135700
# std              14317.198694              0.342487
# min             -39600.000000              0.000000
# 25%              -7200.000000              0.000000
# 50%               7200.000000              0.000000
# 75%               7200.000000              0.000000
# max              46800.000000              1.000000

# %%
df['lang'].value_counts().sort_values(ascending=False)[:15].plot(kind='barh', 
                                                                 figsize=(15,10))
plt.title('Language Distribution', weight='bold', fontsize=18);

# %%
# Basic Tweet analysis
from textblob import TextBlob
tweet = df['text'][2]
print(tweet)
analysis = TextBlob(tweet)
print(f'Polarity: {analysis.sentiment[0]}, Subjectivity: {analysis.sentiment[1]}')
# Out:
# Flew into Gatwick last night. 5 hour drive north. All safe and sound. @gforsterphoto @easyJet
# Polarity: 0.3, Subjectivity: 0.32222222222222224

# %%
df["('user', 'time_zone')"].value_counts()[:15].plot(kind='barh', figsize=(15,5))
plt.title('Time Zone Distribution', weight='bold', fontsize=20);

# %%
# Example tweets
df['text'][:5]
# Out:
# 0    @johnnymowlem @VirginAtlantic @IMSA @BAR1Motor...
# 1    RT @JulieThoin: L'audience reprend. Examen du ...
# 2    Flew into Gatwick last night. 5 hour drive nor...
# 3    👎🏼 what is with Italy...#nopassport control, I...
# 4                Qqun a déjà voyagé avec RyanAir ici ?
# Name: text, dtype: object
