# %%
import sys
import os
sys.path.append("..")

from unzipper import Unzipper
from data_extractor import DataExtractor
from data_wrangler import DataWrangler
from final import Demo
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
print('Unzipping Data')
zipper = Unzipper(os.path.abspath('zipped_data'))
zipper.unzip_all()

print('Extracting Data')
extractor = DataExtractor(directory='unzipped/', features=['id_str', 'text', 'created_at', ('user', 'id_str')])
extractor.make_csv()

print('Creating new features')
wrangler = DataWrangler('extracted_data.csv')
wrangler.full_wrangle()

print('Making plot')
demo = Demo('cleaned_data.csv')
demo.sent_bar()
# Out:
# Unzipping Data
# Skipping: /Users/clepelaars/Desktop/DBL1_repo/demo/zipped_data/.DS_Store
# Unzipping: /Users/clepelaars/Desktop/DBL1_repo/demo/zipped_data/airlines-1464680391642.zip
# Unzipping: /Users/clepelaars/Desktop/DBL1_repo/demo/zipped_data/airlines-1464822271009.zip
# Unzipping: /Users/clepelaars/Desktop/DBL1_repo/demo/zipped_data/airlines-1464723251641.zip
# Unzipping: /Users/clepelaars/Desktop/DBL1_repo/demo/zipped_data/airlines-1464768249072.zip
# Unzipping: /Users/clepelaars/Desktop/DBL1_repo/demo/zipped_data/airlines-1464618733587.zip
# Extracting Data
# Loading file 1/10: airlines-1465161174895.json
# --KeyError at line: [2484]--
# --KeyError at line: [2488]--
# Loading file 2/10: airlines-1464768249072.json
# Loading file 3/10: airlines-1465073304752.json
# Loading file 4/10: airlines-1464723251641.json
# --JSONDecodeError at line: [2935]--
# Loading file 5/10: airlines-1464997463271.json
# Loading file 6/10: airlines-1464947752079.json
# Loading file 7/10: airlines-1464822271009.json
# --KeyError at line: [98995]--
# --KeyError at line: [99051]--
# --KeyError at line: [99301]--
# --KeyError at line: [99385]--
# --KeyError at line: [99395]--
# Loading file 8/10: airlines-1464680391642.json
# --JSONDecodeError at line: [5331]--
# Loading file 9/10: airlines-1464885818551.json
# --KeyError at line: [115800]--
# --KeyError at line: [115821]--
# --KeyError at line: [115823]--
# Loading file 10/10: airlines-1464618733587.json
# --JSONDecodeError at line: [304]--
# Creating new features
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-2-7fe8b2c781bd> in <module>()
#       8
#       9 print('Creating new features')
# ---> 10 wrangler = DataWrangler('extracted_data.csv')
#      11 wrangler.full_wrangle()
#      12
#
# ~/Desktop/DBL1_repo/demo/data_wrangler.py in __init__(self, data)
#      18     """
#      19     def __init__(self, data):
# ---> 20         self.df = pd.read_csv(data)
#      21         self.stopwords = set(stopwords.words('english'))
#      22         self.stemmer = SnowballStemmer("english")
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     453
#     454     try:
# --> 455         data = parser.read(nrows)
#     456     finally:
#     457         parser.close()
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1067                 raise ValueError('skipfooter not supported for iteration')
#    1068
# -> 1069         ret = self._engine.read(nrows)
#    1070
#    1071         if self.options.get('as_recarray'):
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1837     def read(self, nrows=None):
#    1838         try:
# -> 1839             data = self._reader.read(nrows)
#    1840         except StopIteration:
#    1841             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file.
