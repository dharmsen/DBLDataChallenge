# %%
import sys
import os
sys.path.append("..")

from unzipper import Unzipper
from data_extractor import DataExtractor
from data_wrangler import DataWrangler
from final import Demo
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
print('Unzipping Data')
zipper = Unzipper(os.path.abspath('zipped_data'))
zipper.unzip_all()

print('Extracting Data')
extractor = DataExtractor(directory='unzipped/', features=['id_str', 'text', 'created_at', ('user', 'id_str')])
extractor.make_csv()

print('Creating new features')
wrangler = DataWrangler('extracted_data.csv')
wrangler.full_wrangle()

print('Making plot')
demo = Demo('cleaned_data.csv')
demo.sent_bar()
# Out:
# Unzipping Data
# Unzipping: /Users/clepelaars/Desktop/DBL1_repo/demo/zipped_data/airlines-1464680391642.zip
# Unzipping: /Users/clepelaars/Desktop/DBL1_repo/demo/zipped_data/airlines-1464618733587.zip
# Extracting Data
# Loading file 1/2: airlines-1464680391642.json
# --JSONDecodeError at line: [5331]--
# Loading file 2/2: airlines-1464618733587.json
# --JSONDecodeError at line: [304]--
# Creating new features
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Getting sentiments
# Making plot
